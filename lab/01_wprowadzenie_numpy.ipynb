# %% [markdown]
# # 1. Wprowadzenie do pakietu NumPy

# %% [markdown]
# ### Libraries

# %%
import numpy as np

# %% [markdown]
# ## Zadanie 1
# Utwórzyć wektor v zawierający liczby od 10 do 50 co 5.
# Wyznaczyć:
# *   średnią,
# *   odchylenie standardowe,
# *   największy element.

# %%
v = ...

mean = ...
std = ...
max= ...

assert v[0] == 10 and v[-1] == 50
assert np.isclose(mean, 30)
assert max == 50
assert std > 0

# %% [markdown]
# ## Zadanie 2
# Wylosować dwie macierze A i B różnych rozmiarów, a następnie przenożyć je przez siebie macierzowo tak aby otrzymać macierz C rozmiaru 12x4.

# %%
A = ...
B = ...

C = ...

print([m.shape for m in [A, B, C]])

assert A.shape != B.shape
assert C.shape == (12, 4)

# %% [markdown]
# ## Zadanie 3
# Wygenerować macierz 4x4 z losowymi liczbami całkowitymi z zakresu 1-20. Wyznaczyć sumę każdego wiersza oraz sumę każdej kolumny.

# %%
M = ...

sum_rows = np.sum(M, axis=...)
sum_cols = np.sum(M, axis=...)

assert M.shape == (4, 4)
assert sum_rows.shape == (4,)
assert sum_cols.shape == (4,)
assert np.sum(sum_rows) == np.sum(M)

# %% [markdown]
# ## Zadanie 4 - Normalizacja danych
#
# Wygenerować macierz M 100x5 z losowymi wartościami. Znormalizować każdą kolumnę według wzoru:
#
# $$z_{ij} = \frac{x_{ij} - \mu_{j}}{\sigma_{j}}$$

# %%
M = ...

mean = ...
std = ...

M_norm = ...

assert M_norm.shape == (100, 5)
assert np.allclose(np.mean(M_norm, axis=0), 0, atol=1e-10)
assert np.allclose(np.std(M_norm, axis=0), 1, atol=1e-10)
